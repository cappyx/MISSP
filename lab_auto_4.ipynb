# %% [markdown]
# # Production scheduling -- the job shop problem
#
# ## Problem Description
# - We have a number of jobs: Job 0, Job 1, Job 2, ...
# - We have a number of machines: Machine 0, Machine 1, Machine 2, ...
# - Each job must be processed on each machine in a specific order.
# - for example: Job 0 must be processed on Machine 0, then on Machine 1, then on Machine 2.
# - No machine can process more than one job at a time.
# - We assume unlimited buffers between machines, so jobs can immediately move to the next machine if it's available.
# - **Objective**: Minimize the total completion time (makespan), C_max.
#
# the effect of the job shop problem is a schedule, frequentely presented as a Gantt chart.
#
# # ![Job shop problem example](https://www.researchgate.net/publication/370490241/figure/fig1/AS:11431281155279843@1683131798236/Job-sequence-on-machines-for-a-job-shop-problem-with-3-machines-and-2-jobs.png)
#
# The problem is NP-hard, the more jobs and machines, the harder it is to solve.

# %% [markdown]
# ## Mini Problem Example
#
# ### Scenario Setup
# - **Machines**: 0 and 1
# - **Jobs**: 0 and 1
# - Each job has two operations, one on each machine, but in different orders
#
# ### Job 0
# - **Operation 1**: Machine 0 → Processing time = 5
# - **Operation 2**: Machine 1 → Processing time = 6
# - Thus, Job 0 must go first to Machine 0, then to Machine 1
#
# ### Job 1
# - **Operation 1**: Machine 1 → Processing time = 4
# - **Operation 2**: Machine 0 → Processing time = 7
# - Thus, Job 1 must go first to Machine 1, then to Machine 0
#
# ### Objective
# Minimize the makespan (C_max)

# %%
# !pip install pulp

import pulp

# 1) Create the problem
model = pulp.LpProblem("Small_Job_Shop", pulp.LpMinimize)

# 2) Decision variables
# Start times:
# s0_0: Start time of Job 0 on Machine 0
# s0_1: Start time of Job 0 on Machine 1
# s1_0: Start time of Job 1 on Machine 0
# s1_1: Start time of Job 1 on Machine 1
s0_0 = pulp.LpVariable("s0_0", lowBound=0, cat='Continuous')
s0_1 = pulp.LpVariable("s0_1", lowBound=0, cat='Continuous')
s1_0 = pulp.LpVariable("s1_0", lowBound=0, cat='Continuous')
s1_1 = pulp.LpVariable("s1_1", lowBound=0, cat='Continuous')

# Makespan
Cmax = pulp.LpVariable("Cmax", lowBound=0, cat='Continuous')

# 3) Processing times
# Job 0: M0=5, then M1=6
p0_m0 = 3 # processing time of Job 0 on Machine 0
p0_m1 = 6 # processing time of Job 0 on Machine 1

# Job 1: M1=4, then M0=7
p1_m1 = 4 # processing time of Job 1 on Machine 1
p1_m0 = 7 # processing time of Job 1 on Machine 0

# 4) Binary variables for machine usage ordering
# We need these to ensure no overlap on each machine - each machine can process only one job at a time.
# For Machine 0, let y0_01 = 1 if Job 0 finishes before Job 1 starts on M0, else 0.
# For Machine 1, let y1_01 = 1 if Job 0 finishes before Job 1 starts on M1, else 0.
y0_01 = pulp.LpVariable("y0_01", cat='Binary')  # ordering on Machine 0
y1_01 = pulp.LpVariable("y1_01", cat='Binary')  # ordering on Machine 1

# Define a "big M" large enough to cover maximum possible scheduling time
bigM = 9999

# 5) OBJECTIVE: minimize Cmax
model += Cmax, "Minimize_the_makespan"

# 6) CONSTRAINTS

# -- (A) Operation sequence for each job --

# Job 0 must finish on Machine 0 before starting on Machine 1:
model += s0_1 >= s0_0 + p0_m0, "Seq_Job0" # start time of Job 0 on Machine 1 must be greater than or equal to the start time of Job 0 on Machine 0 plus the processing time of Job 0 on Machine 0

# Job 1 must finish on Machine 1 before starting on Machine 0:
model += s1_0 >= s1_1 + p1_m1, "Seq_Job1" # start time of Job 1 on Machine 0 must be greater than or equal to the start time of Job 1 on Machine 1 plus the processing time of Job 1 on Machine 1

# -- (B) No overlap on Machine 0 --
# Machine 0 is used by:
#   - Job 0 (from s0_0 to s0_0 + p0_m0)
#   - Job 1 (from s1_0 to s1_0 + p1_m0)
# Use a big-M approach with binary y0_01:

# If y0_01 = 1, Job0 finishes before Job1 starts on M0:
#     s1_0 >= s0_0 + p0_m0 - bigM*(1 - y0_01)
model += s1_0 >= s0_0 + p0_m0 - bigM*(1 - y0_01), "NoOverlap0a"

# If y0_01 = 0, Job1 finishes before Job0 starts on M0:
#     s0_0 >= s1_0 + p1_m0 - bigM*(y0_01)
model += s0_0 >= s1_0 + p1_m0 - bigM*(y0_01), "NoOverlap0b"

# -- (C) No overlap on Machine 1 --
# Machine 1 is used by:
#   - Job 0 (from s0_1 to s0_1 + p0_m1)
#   - Job 1 (from s1_1 to s1_1 + p1_m1)
# Use a big-M approach with y1_01:

# If y1_01 = 1, Job0 finishes before Job1 starts on M1:
#     s1_1 >= s0_1 + p0_m1 - bigM*(1 - y1_01)
model += s1_1 >= s0_1 + p0_m1 - bigM*(1 - y1_01), "NoOverlap1a"

# If y1_01 = 0, Job1 finishes before Job0 starts on M1:
#     s0_1 >= s1_1 + p1_m1 - bigM*(y1_01)
model += s0_1 >= s1_1 + p1_m1 - bigM*(y1_01), "NoOverlap1b"

# -- (D) Makespan definition --
# Finish time for Job 0 = time it completes on Machine 1 = s0_1 + p0_m1
# Finish time for Job 1 = time it completes on Machine 0 = s1_0 + p1_m0

model += Cmax >= s0_1 + p0_m1, "Makespan_Job0"
model += Cmax >= s1_0 + p1_m0, "Makespan_Job1"

# 7) Solve the model
model.solve(pulp.PULP_CBC_CMD(msg=False))

# 8) Print results
print("Status:", pulp.LpStatus[model.status])
print("Objective (makespan) =", pulp.value(model.objective))

# Decision variable values:
print("--- Start Times ---")
print("s0_0 (Job0 on M0) =", pulp.value(s0_0))
print("s0_1 (Job0 on M1) =", pulp.value(s0_1))
print("s1_0 (Job1 on M0) =", pulp.value(s1_0))
print("s1_1 (Job1 on M1) =", pulp.value(s1_1))

print("--- Binary Orders ---")
print("y0_01 (Machine 0 order) =", pulp.value(y0_01))
print("y1_01 (Machine 1 order) =", pulp.value(y1_01))
# Out:
# ...
# Status: Optimal
# Objective (makespan) = 11.0
# --- Start Times ---
# s0_0 (Job0 on M0) = 0.0
# s0_1 (Job0 on M1) = 4.0
# s1_0 (Job1 on M0) = 4.0
# s1_1 (Job1 on M1) = 0.0
# --- Binary Orders ---
# y0_01 (Machine 0 order) = 1.0
# y1_01 (Machine 1 order) = 0.0

# %%
import matplotlib.pyplot as plt

# Create Gantt chart
fig, ax = plt.subplots(figsize=(10, 6))

# Colors for each job
colors = ['#FF9999', '#66B2FF']

# For each machine
for m in range(2):
    # Plot Job 0 on this machine
    if m == 0:
        start = pulp.value(s0_0)
        duration = p0_m0
    else:
        start = pulp.value(s0_1)
        duration = p0_m1
    ax.barh(m, duration, left=start, color=colors[0], label='Job 0' if m==0 else "")

    # Plot Job 1 on this machine
    if m == 0:
        start = pulp.value(s1_0)
        duration = p1_m0
    else:
        start = pulp.value(s1_1)
        duration = p1_m1
    ax.barh(m, duration, left=start, color=colors[1], label='Job 1' if m==0 else "")

# Customize the chart
ax.set_yticks(range(2))
ax.set_yticklabels(['Machine 0', 'Machine 1'])
ax.set_xlabel('Time')
ax.set_title('Job Shop Schedule')
ax.grid(True)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Excercise 1
#
# Play with the code above to see how the schedule changes with different processing times.

# %% [markdown]
# #More general job shop problem example
#
# ## Data Setup
# Let's define for each job:
# - The machine sequence the job must follow
# - The processing time on each machine (in hours)
#
# ### Job Specifications:
#
# **Job 0:**
# - Machine sequence: Machine 0 → Machine 1 → Machine 2
# - Processing times: 5, 6, 4 hours respectively
#
# **Job 1:**
# - Machine sequence: Machine 1 → Machine 2 → Machine 0
# - Processing times: 4, 3, 7 hours respectively
#
# **Job 2:**
# - Machine sequence: Machine 0 → Machine 2 → Machine 1
# - Processing times: 6, 4, 5 hours respectively
#
# We will store this data in two parallel 2D lists:
# - `machine_order`: Contains the sequence of machines for each job
# - `processing_time`: Contains the corresponding processing times

# %%
#!pip install pulp

import pulp

# -------------------------
# 1) PROBLEM PARAMETERS
# -------------------------
num_jobs = 3
num_machines = 3

# machine_order[job] = list of machines in the order they must be processed
# Example: Job 0 -> Machine 0 -> Machine 1 -> Machine 2
machine_order = [
    [0, 1, 2],  # Job 0
    [1, 2, 0],  # Job 1
    [0, 2, 1]   # Job 2
]

# processing_time[job] = list of processing times for each operation in the sequence
# For Job 0: 5 hours on Machine 0, 6 hours on Machine 1, 4 hours on Machine 2
processing_time = [
    [5, 6, 4],  # Job 0
    [4, 3, 7],  # Job 1
    [6, 4, 5]   # Job 2
]

# -------------------------
# 2) DECISION VARIABLES
# -------------------------
# We'll create a variable start_time[m, j] = the start time of Job j on Machine m.
# Because each job visits each machine exactly once (in a known order), we can define variables for each (m, j).
# Alternatively, we might define them only in operation order; for simplicity, we'll define them for (m, j).
start_time = pulp.LpVariable.dicts(
    "start_time",
    [(m, j) for m in range(num_machines) for j in range(num_jobs)],
    lowBound=0,
    cat='Continuous'
)

# We'll create a variable Cmax to represent the makespan (the maximum finishing time).
Cmax = pulp.LpVariable('Cmax', lowBound=0, cat='Continuous')

# -------------------------
# 3) MODEL
# -------------------------
model = pulp.LpProblem("Job_Shop_Scheduling", pulp.LpMinimize)

# Objective: Minimize the makespan
model += Cmax, "Minimize_makespan"

# -------------------------
# 4) CONSTRAINTS
# -------------------------

# (A) **Operation sequence** constraints:
#     For each job j, each operation must start after the previous one finishes.

for j in range(num_jobs):
    for op in range(num_machines - 1):
        current_machine = machine_order[j][op]
        next_machine = machine_order[j][op + 1]

        current_op_time = processing_time[j][op]

        # The start of the next operation must be >= (start of current operation + processing time).
        model += start_time[next_machine, j] >= (
            start_time[current_machine, j] + current_op_time
        ), f"SequenceConstraint_Job{j}_Op{op}"

# (B) **No overlap on the same machine**:
#     If two jobs j1 and j2 require the same machine m, only one can run at a time.
#     We'll use the "big-M" approach with binary variables to enforce non-overlapping intervals.

# Big M can be a large enough number. For a small example, let's pick something > sum of all times.
bigM = 9999

# Create binary variables that indicate ordering between job pairs on each machine.
# y[m, j1, j2] = 1 means job j1 finishes before job j2 starts (on machine m).
y = pulp.LpVariable.dicts(
    "y",
    [(m, j1, j2) for m in range(num_machines) for j1 in range(num_jobs) for j2 in range(num_jobs) if j1 != j2],
    cat='Binary'
)

for m in range(num_machines):
    # Retrieve jobs that run on machine m, but we actually know each job runs on m exactly once in some order
    # We just loop over all pairs j1, j2.
    for j1 in range(num_jobs):
        for j2 in range(num_jobs):
            if j1 != j2:
                # processing time of job j1 on machine m
                # We need to figure out which operation index job j1 uses machine m
                op_j1 = machine_order[j1].index(m)  # index of machine m in job j1's sequence
                proc_j1 = processing_time[j1][op_j1]

                op_j2 = machine_order[j2].index(m)
                proc_j2 = processing_time[j2][op_j2]

                # Non-overlap constraints:
                # start_time[m, j2] >= start_time[m, j1] + proc_j1 - bigM*(1 - y[m, j1, j2])
                model += start_time[m, j2] >= start_time[m, j1] + proc_j1 - bigM * (1 - y[m, j1, j2])

                # Similarly:
                # start_time[m, j1] >= start_time[m, j2] + proc_j2 - bigM*(y[m, j1, j2])
                model += start_time[m, j1] >= start_time[m, j2] + proc_j2 - bigM * (y[m, j1, j2])

# (C) **Makespan definition**:
#     For each job j, the finishing time on its last machine must be <= Cmax.
for j in range(num_jobs):
    # last machine index for job j (the job visits machines in a known order)
    last_machine = machine_order[j][-1]
    # last operation index (which is num_machines - 1)
    last_op_idx = num_machines - 1
    finish_time_j = start_time[last_machine, j] + processing_time[j][last_op_idx]

    model += Cmax >= finish_time_j, f"CmaxConstraint_Job{j}"

# -------------------------
# 5) SOLVE
# -------------------------
model.solve(pulp.PULP_CBC_CMD(msg=False))

print("Solution Status:", pulp.LpStatus[model.status])
print("Objective (makespan) =", pulp.value(model.objective))

# Print the start times
for (m, j) in start_time:
    print(f"Start time of Job {j} on Machine {m} = {pulp.value(start_time[m, j])}")
# Out:
# Solution Status: Optimal
# Objective (makespan) = 20.0
# Start time of Job 0 on Machine 0 = 0.0
# Start time of Job 1 on Machine 0 = 11.0
# Start time of Job 2 on Machine 0 = 5.0
# Start time of Job 0 on Machine 1 = 5.0
# Start time of Job 1 on Machine 1 = 0.0
# Start time of Job 2 on Machine 1 = 15.0
# Start time of Job 0 on Machine 2 = 15.0
# Start time of Job 1 on Machine 2 = 4.0
# Start time of Job 2 on Machine 2 = 11.0

# %%
# Create Gantt chart
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import colorsys

# Set up the plot with dynamic sizing based on number of machines
fig_height = max(6, num_machines * 0.5)  # Increase height for many machines
fig, ax = plt.subplots(figsize=(12, fig_height))

# Generate colors dynamically based on number of jobs
def generate_colors(n):
    colors = []
    for i in range(n):
        hue = i / n
        saturation = 0.7
        value = 0.9
        rgb = colorsys.hsv_to_rgb(hue, saturation, value)
        colors.append(rgb)
    return colors

colors = generate_colors(num_jobs)

# For each machine and job
for m in range(num_machines):
    for j in range(num_jobs):
        # Get start time and processing time
        start = pulp.value(start_time[m, j])
        op_idx = machine_order[j].index(m)
        duration = processing_time[j][op_idx]

        # Calculate rectangle height based on number of machines
        rect_height = min(0.8, 0.95 - (0.01 * num_machines))

        # Create rectangle for this operation
        rect = patches.Rectangle(
            (start, m),                     # (x,y)
            duration,                       # width
            rect_height,                    # height
            facecolor=colors[j],
            edgecolor='black',
            alpha=0.7
        )

        # Add rectangle to plot
        ax.add_patch(rect)

        # Adjust text size based on number of jobs and machines
        text_size = max(8, min(10, 200/(num_jobs * num_machines)))

        # Add job number text in the middle of rectangle
        ax.text(start + duration/2, m + rect_height/2, f'J{j}',
                horizontalalignment='center',
                verticalalignment='center',
                fontsize=text_size)

# Customize the plot
ax.set_ylim(-0.5, num_machines - 0.5)
ax.set_xlim(0, pulp.value(Cmax) * 1.05)  # Add 5% margin

# Adjust tick label size based on number of machines
tick_size = max(8, min(10, 120/num_machines))
ax.set_yticks(range(num_machines))
ax.set_yticklabels([f'Machine {m}' for m in range(num_machines)], fontsize=tick_size)
ax.set_xlabel('Time', fontsize=tick_size)
ax.grid(True, axis='x', linestyle='--', alpha=0.7)

plt.title('Job Shop Schedule - Gantt Chart', pad=20, fontsize=tick_size + 2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Excercise 1b:
# Play with the code above, see how the Cmax changes with different processing times, different variations of the problem.

# %%
import pulp
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import colorsys

# --------------------------------------------------
# 1) PROBLEM PARAMETERS (User-modifiable section)
# --------------------------------------------------
# Define the number of jobs and machines
num_jobs = 3
num_machines = 3

# Define the machine sequence for each job
# machine_order[job_idx] = [machine_for_op1, machine_for_op2, ...]
machine_order = [
    [0, 1, 2],  # Job 0: M0 -> M1 -> M2
    [1, 2, 0],  # Job 1: M1 -> M2 -> M0
    [0, 2, 1]   # Job 2: M0 -> M2 -> M1
]

# Define processing times for each operation of each job
# processing_time[job_idx] = [time_for_op1, time_for_op2, ...]
processing_time = [
    [5, 6, 4],  # Job 0: 5h on M0, 6h on M1, 4h on M2
    [4, 3, 7],  # Job 1: 4h on M1, 3h on M2, 7h on M0
    [6, 4, 5]   # Job 2: 6h on M0, 4h on M2, 5h on M1
]

# Validate input dimensions
if len(machine_order) != num_jobs or len(processing_time) != num_jobs:
    raise ValueError("Number of jobs in machine_order/processing_time does not match num_jobs")
for j in range(num_jobs):
    if len(machine_order[j]) != num_machines or len(processing_time[j]) != num_machines:
        raise ValueError(f"Job {j} does not have {num_machines} operations. Check machine_order and processing_time lists.")

# Define a "big M" for non-overlap constraints, chosen large enough
bigM = sum(sum(p) for p in processing_time) + 100 # Sum of all processing times + buffer

# --------------------------------------------------
# 2) PuLP Model Setup
# --------------------------------------------------
model = pulp.LpProblem("Job_Shop_Scheduling", pulp.LpMinimize)

# --------------------------------------------------
# 3) Decision Variables
# --------------------------------------------------
# start_time[machine_idx, job_idx]: start time of Job j on Machine m
start_time = pulp.LpVariable.dicts(
    "start_time",
    [(m, j) for m in range(num_machines) for j in range(num_jobs)],
    lowBound=0,
    cat='Continuous'
)

# Cmax: The overall makespan (maximum finishing time)
Cmax = pulp.LpVariable('Cmax', lowBound=0, cat='Continuous')

# Binary variables for machine usage ordering (y[m, j1, j2] = 1 if j1 finishes before j2 on m)
# We only define y for unique pairs (j1, j2) where j1 < j2.
# The order for (j2, j1) will be implicitly handled by 1 - y[m, j1, j2].
y = pulp.LpVariable.dicts(
    "y",
    [(m, j1, j2) for m in range(num_machines) for j1 in range(num_jobs) for j2 in range(j1 + 1, num_jobs)],
    cat='Binary'
)

# --------------------------------------------------
# 4) Objective Function
# --------------------------------------------------
model += Cmax, "Minimize_makespan"

# --------------------------------------------------
# 5) Constraints
# --------------------------------------------------

# (A) Operation sequence constraints for each job:
# Each operation must start after the previous one for the same job finishes.
for j in range(num_jobs):
    for op_idx in range(num_machines - 1):
        current_machine = machine_order[j][op_idx]
        next_machine = machine_order[j][op_idx + 1]
        current_op_duration = processing_time[j][op_idx]

        model += (start_time[next_machine, j] >= (start_time[current_machine, j] + current_op_duration)), \
                 f"Seq_Job{j}_Op{op_idx}_M{current_machine}_M{next_machine}"

# (B) No overlap on the same machine constraints:
# Only one job can run on a machine at any given time.
# We iterate through unique pairs (j1, j2) where j1 < j2
for m in range(num_machines):
    for j1 in range(num_jobs):
        for j2 in range(j1 + 1, num_jobs): # Only iterate for j2 > j1 to process each pair once
            # Determine the operation index for job j1 on machine m
            try:
                op_idx_j1 = machine_order[j1].index(m)
                proc_j1_on_m = processing_time[j1][op_idx_j1]
            except ValueError:
                # This means job j1 does not use machine m, which should not happen
                # given the problem definition where each job uses each machine once.
                continue

            # Determine the operation index for job j2 on machine m
            try:
                op_idx_j2 = machine_order[j2].index(m)
                proc_j2_on_m = processing_time[j2][op_idx_j2]
            except ValueError:
                # Same as above for j2
                continue

            # Non-overlap constraints using big-M and binary variable y[m, j1, j2]
            # y[m, j1, j2] = 1 means j1 finishes before j2 on machine m.

            # If y[m, j1, j2] = 1, then j1 runs before j2 on machine m:
            model += (start_time[m, j2] >= start_time[m, j1] + proc_j1_on_m - bigM * (1 - y[m, j1, j2])), \
                     f"NoOverlap_M{m}_J{j1}_before_J{j2}"

            # If y[m, j1, j2] = 0, then j2 runs before j1 on machine m:
            model += (start_time[m, j1] >= start_time[m, j2] + proc_j2_on_m - bigM * (y[m, j1, j2])), \
                     f"NoOverlap_M{m}_J{j2}_before_J{j1}"

# (C) Makespan definition constraints:
# Cmax must be greater than or equal to the finish time of the last operation for every job.
for j in range(num_jobs):
    last_machine_for_job = machine_order[j][-1] # The last machine in the sequence for job j
    last_op_duration_for_job = processing_time[j][-1] # The processing time for the last operation

    finish_time_job_j = start_time[last_machine_for_job, j] + last_op_duration_for_job
    model += Cmax >= finish_time_job_j, f"Cmax_Job{j}_finish"

# --------------------------------------------------
# 6) Solve the Model
# --------------------------------------------------
print("Solving the Job Shop Problem...")
model.solve(pulp.PULP_CBC_CMD(msg=False))

# --------------------------------------------------
# 7) Print Results
# --------------------------------------------------
print("\n--- Solution Status ---")
print("Status:", pulp.LpStatus[model.status])
print("Objective (makespan) =", pulp.value(model.objective))

print("\n--- Start Times (Machine, Job) ---")
# Sort for cleaner output
sorted_start_times = sorted(start_time.items(), key=lambda x: (x[0][0], x[0][1]))
for (m, j), var in sorted_start_times:
    print(f"Start time of Job {j} on Machine {m} = {pulp.value(var)}")

# --------------------------------------------------
# 8) Generate Gantt Chart
# --------------------------------------------------

# Create Gantt chart figure and axes
fig_height = max(6, num_machines * 0.7) # Adjust height dynamically
fig, ax = plt.subplots(figsize=(14, fig_height))

# Generate distinct colors for each job
def generate_colors(n):
    colors = []
    for i in range(n):
        hue = i / n
        saturation = 0.7
        value = 0.9
        rgb = colorsys.hsv_to_rgb(hue, saturation, value)
        colors.append(rgb)
    return colors

j_colors = generate_colors(num_jobs)

# Plot operations for each job on each machine
for j in range(num_jobs):
    for op_idx in range(num_machines):
        m = machine_order[j][op_idx]
        start = pulp.value(start_time[m, j])
        duration = processing_time[j][op_idx]

        # Create rectangle for the operation
        rect_height = 0.7 # Height of the bar on the Gantt chart
        rect = patches.Rectangle(
            (start, m - rect_height/2), # (x, y) starting point
            duration,                    # width
            rect_height,                 # height
            facecolor=j_colors[j],
            edgecolor='black',
            alpha=0.8
        )
        ax.add_patch(rect)

        # Add job and machine text label inside the bar
        text_size = max(6, min(12, 100 / (num_jobs * num_machines))) # Dynamic font size
        ax.text(start + duration / 2, m, f'J{j} M{m}',
                horizontalalignment='center',
                verticalalignment='center',
                color='white' if sum(j_colors[j]) < 1.5 else 'black', # Choose text color for contrast
                fontsize=text_size,
                fontweight='bold')

# Customize the chart aesthetics
ax.set_ylim(-0.5, num_machines - 0.5)
ax.set_xlim(0, pulp.value(Cmax) * 1.1) # Add 10% margin on x-axis

ax.set_yticks(range(num_machines))
ax.set_yticklabels([f'Machine {i}' for i in range(num_machines)])
ax.set_xlabel('Time')
ax.set_ylabel('Machine')
ax.set_title(f'Job Shop Schedule (Makespan: {pulp.value(Cmax):.2f})', pad=20)
ax.grid(True, axis='x', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Solving the Job Shop Problem...
#
# --- Solution Status ---
# Status: Optimal
# Objective (makespan) = 20.0
#
# --- Start Times (Machine, Job) ---
# Start time of Job 0 on Machine 0 = 0.0
# Start time of Job 1 on Machine 0 = 11.0
# Start time of Job 2 on Machine 0 = 5.0
# Start time of Job 0 on Machine 1 = 5.0
# Start time of Job 1 on Machine 1 = 0.0
# Start time of Job 2 on Machine 1 = 15.0
# Start time of Job 0 on Machine 2 = 15.0
# Start time of Job 1 on Machine 2 = 4.0
# Start time of Job 2 on Machine 2 = 11.0

# %% [markdown]
# # Excercise 2
# Add a machine to the problem. Use %%timeit to see how the solver performance changes

# %%
import pulp
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import colorsys

# --------------------------------------------------
# 1) PROBLEM PARAMETERS (User-modifiable section)
# --------------------------------------------------
# Define the number of jobs and machines
num_jobs = 3
num_machines = 4  # Increased to 4 machines

# Define the machine sequence for each job
# machine_order[job_idx] = [machine_for_op1, machine_for_op2, ...]
machine_order = [
    [0, 1, 2, 3],  # Job 0: M0 -> M1 -> M2 -> M3
    [1, 2, 0, 3],  # Job 1: M1 -> M2 -> M0 -> M3
    [0, 2, 1, 3]   # Job 2: M0 -> M2 -> M1 -> M3
]

# Define processing times for each operation of each job
# processing_time[job_idx] = [time_for_op1, time_for_op2, ...]
processing_time = [
    [5, 6, 4, 7],  # Job 0: 5h on M0, 6h on M1, 4h on M2, 7h on M3
    [4, 3, 7, 5],  # Job 1: 4h on M1, 3h on M2, 7h on M0, 5h on M3
    [6, 4, 5, 6]   # Job 2: 6h on M0, 4h on M2, 5h on M1, 6h on M3
]

# Validate input dimensions
if len(machine_order) != num_jobs or len(processing_time) != num_jobs:
    raise ValueError("Number of jobs in machine_order/processing_time does not match num_jobs")
for j in range(num_jobs):
    if len(machine_order[j]) != num_machines or len(processing_time[j]) != num_machines:
        raise ValueError(f"Job {j} does not have {num_machines} operations. Check machine_order and processing_time lists.")

# Define a "big M" for non-overlap constraints, chosen large enough
bigM = sum(sum(p) for p in processing_time) + 100 # Sum of all processing times + buffer

# --------------------------------------------------
# 2) PuLP Model Setup
# --------------------------------------------------
model = pulp.LpProblem("Job_Shop_Scheduling", pulp.LpMinimize)

# --------------------------------------------------
# 3) Decision Variables
# --------------------------------------------------
# start_time[machine_idx, job_idx]: start time of Job j on Machine m
start_time = pulp.LpVariable.dicts(
    "start_time",
    [(m, j) for m in range(num_machines) for j in range(num_jobs)],
    lowBound=0,
    cat='Continuous'
)

# Cmax: The overall makespan (maximum finishing time)
Cmax = pulp.LpVariable('Cmax', lowBound=0, cat='Continuous')

# Binary variables for machine usage ordering (y[m, j1, j2] = 1 if j1 finishes before j2 on m)
# We only define y for unique pairs (j1, j2) where j1 < j2.
# The order for (j2, j1) will be implicitly handled by 1 - y[m, j1, j2].
y = pulp.LpVariable.dicts(
    "y",
    [(m, j1, j2) for m in range(num_machines) for j1 in range(num_jobs) for j2 in range(j1 + 1, num_jobs)],
    cat='Binary'
)

# --------------------------------------------------
# 4) Objective Function
# --------------------------------------------------
model += Cmax, "Minimize_makespan"

# --------------------------------------------------
# 5) Constraints
# --------------------------------------------------

# (A) Operation sequence constraints for each job:
# Each operation must start after the previous one for the same job finishes.
for j in range(num_jobs):
    for op_idx in range(num_machines - 1):
        current_machine = machine_order[j][op_idx]
        next_machine = machine_order[j][op_idx + 1]
        current_op_duration = processing_time[j][op_idx]

        model += (start_time[next_machine, j] >= (start_time[current_machine, j] + current_op_duration)), \
                 f"Seq_Job{j}_Op{op_idx}_M{current_machine}_M{next_machine}"

# (B) No overlap on the same machine constraints:
# Only one job can run on a machine at any given time.
# We iterate through unique pairs (j1, j2) where j1 < j2
for m in range(num_machines):
    for j1 in range(num_jobs):
        for j2 in range(j1 + 1, num_jobs): # Only iterate for j2 > j1 to process each pair once
            # Determine the operation index for job j1 on machine m
            try:
                op_idx_j1 = machine_order[j1].index(m)
                proc_j1_on_m = processing_time[j1][op_idx_j1]
            except ValueError:
                # This means job j1 does not use machine m, which should not happen
                # given the problem definition where each job uses each machine once.
                continue

            # Determine the operation index for job j2 on machine m
            try:
                op_idx_j2 = machine_order[j2].index(m)
                proc_j2_on_m = processing_time[j2][op_idx_j2]
            except ValueError:
                # Same as above for j2
                continue

            # Non-overlap constraints using big-M and binary variable y[m, j1, j2]
            # y[m, j1, j2] = 1 means j1 finishes before j2 on machine m.

            # If y[m, j1, j2] = 1, then j1 runs before j2 on machine m:
            model += (start_time[m, j2] >= start_time[m, j1] + proc_j1_on_m - bigM * (1 - y[m, j1, j2])), \
                     f"NoOverlap_M{m}_J{j1}_before_J{j2}"

            # If y[m, j1, j2] = 0, then j2 runs before j1 on machine m:
            model += (start_time[m, j1] >= start_time[m, j2] + proc_j2_on_m - bigM * (y[m, j1, j2])), \
                     f"NoOverlap_M{m}_J{j2}_before_J{j1}"

# (C) Makespan definition constraints:
# Cmax must be greater than or equal to the finish time of the last operation for every job.
for j in range(num_jobs):
    last_machine_for_job = machine_order[j][-1] # The last machine in the sequence for job j
    last_op_duration_for_job = processing_time[j][-1] # The processing time for the last operation

    finish_time_job_j = start_time[last_machine_for_job, j] + last_op_duration_for_job
    model += Cmax >= finish_time_job_j, f"Cmax_Job{j}_finish"

# --------------------------------------------------
# 6) Solve the Model
# --------------------------------------------------
print("Solving the Job Shop Problem...")
# %timeit -n 1 -r 1 model.solve(pulp.PULP_CBC_CMD(msg=False))

# --------------------------------------------------
# 7) Print Results
# --------------------------------------------------
print("\n--- Solution Status ---")
print("Status:", pulp.LpStatus[model.status])
print("Objective (makespan) =", pulp.value(model.objective))

print("\n--- Start Times (Machine, Job) ---")
# Sort for cleaner output
sorted_start_times = sorted(start_time.items(), key=lambda x: (x[0][0], x[0][1]))
for (m, j), var in sorted_start_times:
    print(f"Start time of Job {j} on Machine {m} = {pulp.value(var)}")

# --------------------------------------------------
# 8) Generate Gantt Chart
# --------------------------------------------------

# Create Gantt chart figure and axes
fig_height = max(6, num_machines * 0.7) # Adjust height dynamically
fig, ax = plt.subplots(figsize=(14, fig_height))

# Generate distinct colors for each job
def generate_colors(n):
    colors = []
    for i in range(n):
        hue = i / n
        saturation = 0.7
        value = 0.9
        rgb = colorsys.hsv_to_rgb(hue, saturation, value)
        colors.append(rgb)
    return colors

j_colors = generate_colors(num_jobs)

# Plot operations for each job on each machine
for j in range(num_jobs):
    for op_idx in range(num_machines):
        m = machine_order[j][op_idx]
        start = pulp.value(start_time[m, j])
        duration = processing_time[j][op_idx]

        # Create rectangle for the operation
        rect_height = 0.7 # Height of the bar on the Gantt chart
        rect = patches.Rectangle(
            (start, m - rect_height/2), # (x, y) starting point
            duration,                    # width
            rect_height,                 # height
            facecolor=j_colors[j],
            edgecolor='black',
            alpha=0.8
        )
        ax.add_patch(rect)

        # Add job and machine text label inside the bar
        text_size = max(6, min(12, 100 / (num_jobs * num_machines))) # Dynamic font size
        ax.text(start + duration / 2, m, f'J{j} M{m}',
                horizontalalignment='center',
                verticalalignment='center',
                color='white' if sum(j_colors[j]) < 1.5 else 'black', # Choose text color for contrast
                fontsize=text_size,
                fontweight='bold')

# Customize the chart aesthetics
ax.set_ylim(-0.5, num_machines - 0.5)
ax.set_xlim(0, pulp.value(Cmax) * 1.1) # Add 10% margin on x-axis

ax.set_yticks(range(num_machines))
ax.set_yticklabels([f'Machine {i}' for i in range(num_machines)])
ax.set_xlabel('Time')
ax.set_ylabel('Machine')
ax.set_title(f'Job Shop Schedule (Makespan: {pulp.value(Cmax):.2f})', pad=20)
ax.grid(True, axis='x', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Solving the Job Shop Problem...
# 39.7 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
#
# --- Solution Status ---
# Status: Optimal
# Objective (makespan) = 33.0
#
# --- Start Times (Machine, Job) ---
# Start time of Job 0 on Machine 0 = 9.0
# Start time of Job 1 on Machine 0 = 14.0
# Start time of Job 2 on Machine 0 = 0.0
# Start time of Job 0 on Machine 1 = 15.0
# Start time of Job 1 on Machine 1 = 0.0
# Start time of Job 2 on Machine 1 = 10.0
# Start time of Job 0 on Machine 2 = 21.0
# Start time of Job 1 on Machine 2 = 11.0
# Start time of Job 2 on Machine 2 = 6.0
# Start time of Job 0 on Machine 3 = 26.0
# Start time of Job 1 on Machine 3 = 21.0
# Start time of Job 2 on Machine 3 = 15.0

# %% [markdown]
# # Excercise 3:
#
# Make the problem interactive, add a way to specify the number of jobs and machines interactively

# %%
import pulp
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import colorsys
import ipywidgets as widgets
from IPython.display import display
import random

def solve_and_visualize_job_shop(num_jobs, num_machines):
    # --------------------------------------------------
    # 1) PROBLEM PARAMETERS (Dynamically generated)
    # --------------------------------------------------
    print(f"Generating Job Shop Problem with {num_jobs} jobs and {num_machines} machines...")

    # Dynamically generate machine_order
    machine_order = []
    for _ in range(num_jobs):
        # Each job visits each machine exactly once in a random order
        machine_order.append(random.sample(range(num_machines), num_machines))

    # Dynamically generate processing_time
    processing_time = []
    for _ in range(num_jobs):
        job_times = []
        for _ in range(num_machines):
            job_times.append(random.randint(1, 10)) # Random processing time between 1 and 10
        processing_time.append(job_times)

    # Validate input dimensions (already handled by generation logic, but good for explicit check)
    if len(machine_order) != num_jobs or len(processing_time) != num_jobs:
        raise ValueError("Number of jobs in machine_order/processing_time does not match num_jobs")
    for j in range(num_jobs):
        if len(machine_order[j]) != num_machines or len(processing_time[j]) != num_machines:
            raise ValueError(f"Job {j} does not have {num_machines} operations. Check machine_order and processing_time lists.")

    # Define a "big M" for non-overlap constraints, chosen large enough
    bigM = sum(sum(p) for p in processing_time) + 100 # Sum of all processing times + buffer

    # --------------------------------------------------
    # 2) PuLP Model Setup
    # --------------------------------------------------
    model = pulp.LpProblem("Job_Shop_Scheduling", pulp.LpMinimize)

    # --------------------------------------------------
    # 3) Decision Variables
    # --------------------------------------------------
    # start_time[machine_idx, job_idx]: start time of Job j on Machine m
    start_time = pulp.LpVariable.dicts(
        "start_time",
        [(m, j) for m in range(num_machines) for j in range(num_jobs)],
        lowBound=0,
        cat='Continuous'
    )

    # Cmax: The overall makespan (maximum finishing time)
    Cmax = pulp.LpVariable('Cmax', lowBound=0, cat='Continuous')

    # Binary variables for machine usage ordering (y[m, j1, j2] = 1 if j1 finishes before j2 on m)
    # We only define y for unique pairs (j1, j2) where j1 < j2.
    # The order for (j2, j1) will be implicitly handled by 1 - y[m, j1, j2].
    y = pulp.LpVariable.dicts(
        "y",
        [(m, j1, j2) for m in range(num_machines) for j1 in range(num_jobs) for j2 in range(j1 + 1, num_jobs)],
        cat='Binary'
    )

    # --------------------------------------------------
    # 4) Objective Function
    # --------------------------------------------------
    model += Cmax, "Minimize_makespan"

    # --------------------------------------------------
    # 5) Constraints
    # --------------------------------------------------

    # (A) Operation sequence constraints for each job:
    # Each operation must start after the previous one for the same job finishes.
    for j in range(num_jobs):
        for op_idx in range(num_machines - 1):
            current_machine = machine_order[j][op_idx]
            next_machine = machine_order[j][op_idx + 1]
            current_op_duration = processing_time[j][op_idx]

            model += (start_time[next_machine, j] >= (start_time[current_machine, j] + current_op_duration)), \
                     f"Seq_Job{j}_Op{op_idx}_M{current_machine}_M{next_machine}"

    # (B) No overlap on the same machine constraints:
    # Only one job can run on a machine at any given time.
    # We iterate through unique pairs (j1, j2) where j1 < j2
    for m in range(num_machines):
        for j1 in range(num_jobs):
            for j2 in range(j1 + 1, num_jobs): # Only iterate for j2 > j1 to process each pair once
                # Determine the operation index for job j1 on machine m
                try:
                    op_idx_j1 = machine_order[j1].index(m)
                    proc_j1_on_m = processing_time[j1][op_idx_j1]
                except ValueError:
                    # This means job j1 does not use machine m, which should not happen
                    # given the problem definition where each job uses each machine once.
                    continue

                # Determine the operation index for job j2 on machine m
                try:
                    op_idx_j2 = machine_order[j2].index(m)
                    proc_j2_on_m = processing_time[j2][op_idx_j2]
                except ValueError:
                    # Same as above for j2
                    continue

                # Non-overlap constraints using big-M and binary variable y[m, j1, j2]
                # y[m, j1, j2] = 1 means j1 finishes before j2 on machine m.

                # If y[m, j1, j2] = 1, then j1 runs before j2 on machine m:
                model += (start_time[m, j2] >= start_time[m, j1] + proc_j1_on_m - bigM * (1 - y[m, j1, j2])), \
                         f"NoOverlap_M{m}_J{j1}_before_J{j2}"

                # If y[m, j1, j2] = 0, then j2 runs before j1 on machine m:
                model += (start_time[m, j1] >= start_time[m, j2] + proc_j2_on_m - bigM * (y[m, j1, j2])), \
                         f"NoOverlap_M{m}_J{j2}_before_J{j1}"

    # (C) Makespan definition constraints:
    # Cmax must be greater than or equal to the finish time of the last operation for every job.
    for j in range(num_jobs):
        last_machine_for_job = machine_order[j][-1] # The last machine in the sequence for job j
        last_op_duration_for_job = processing_time[j][-1] # The processing time for the last operation

        finish_time_job_j = start_time[last_machine_for_job, j] + last_op_duration_for_job
        model += Cmax >= finish_time_job_j, f"Cmax_Job{j}_finish"

    # --------------------------------------------------
    # 6) Solve the Model
    # --------------------------------------------------
    print("Solving the Job Shop Problem...")
    model.solve(pulp.PULP_CBC_CMD(msg=False))

    # --------------------------------------------------
    # 7) Print Results
    # --------------------------------------------------
    print("\n--- Solution Status ---")
    print("Status:", pulp.LpStatus[model.status])
    print("Objective (makespan) =", pulp.value(model.objective))

    print("\n--- Start Times (Machine, Job) ---")
    # Sort for cleaner output
    sorted_start_times = sorted(start_time.items(), key=lambda x: (x[0][0], x[0][1]))
    for (m, j), var in sorted_start_times:
        print(f"Start time of Job {j} on Machine {m} = {pulp.value(var)}")

    # --------------------------------------------------
    # 8) Generate Gantt Chart
    # --------------------------------------------------

    # Create Gantt chart figure and axes
    fig_height = max(6, num_machines * 0.7) # Adjust height dynamically
    fig, ax = plt.subplots(figsize=(14, fig_height))

    # Generate distinct colors for each job
    def generate_colors(n):
        colors = []
        for i in range(n):
            hue = i / n
            saturation = 0.7
            value = 0.9
            rgb = colorsys.hsv_to_rgb(hue, saturation, value)
            colors.append(rgb)
        return colors

    j_colors = generate_colors(num_jobs)

    # Plot operations for each job on each machine
    for j in range(num_jobs):
        for op_idx in range(num_machines):
            m = machine_order[j][op_idx]
            start = pulp.value(start_time[m, j])
            duration = processing_time[j][op_idx]

            # Create rectangle for the operation
            rect_height = 0.7 # Height of the bar on the Gantt chart
            rect = patches.Rectangle(
                (start, m - rect_height/2), # (x, y) starting point
                duration,                    # width
                rect_height,                 # height
                facecolor=j_colors[j],
                edgecolor='black',
                alpha=0.8
            )
            ax.add_patch(rect)

            # Add job and machine text label inside the bar
            text_size = max(6, min(12, 100 / (num_jobs * num_machines))) # Dynamic font size
            ax.text(start + duration / 2, m, f'J{j} M{m}',
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if sum(j_colors[j]) < 1.5 else 'black', # Choose text color for contrast
                    fontsize=text_size,
                    fontweight='bold')

    # Customize the chart aesthetics
    ax.set_ylim(-0.5, num_machines - 0.5)
    ax.set_xlim(0, pulp.value(Cmax) * 1.1) # Add 10% margin on x-axis

    ax.set_yticks(range(num_machines))
    ax.set_yticklabels([f'Machine {i}' for i in range(num_machines)])
    ax.set_xlabel('Time')
    ax.set_ylabel('Machine')
    ax.set_title(f'Job Shop Schedule (Makespan: {pulp.value(Cmax):.2f})', pad=20)
    ax.grid(True, axis='x', linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()

# Create interactive sliders
num_jobs_slider = widgets.IntSlider(
    value=3,
    min=2,
    max=5,
    step=1,
    description='Number of Jobs:',
    continuous_update=False
)

num_machines_slider = widgets.IntSlider(
    value=3,
    min=2,
    max=5,
    step=1,
    description='Number of Machines:',
    continuous_update=False
)

# Use interact to link the function to the sliders
print("Adjust the sliders below to dynamically generate and solve job shop problems:")
widgets.interactive(solve_and_visualize_job_shop, num_jobs=num_jobs_slider, num_machines=num_machines_slider)
# Out:
# Adjust the sliders below to dynamically generate and solve job shop problems:
# interactive(children=(IntSlider(value=3, continuous_update=False, description='Number of Jobs:', max=5, min=2)…

# %% [markdown]
# The problem can be very hard for a larger number of jobs and machines. There are some heuristics that can be used to solve it. Some interesting methods are:
# - Genetic algorithms
# - Simulated annealing
# - Tabu search
# - Ant colony optimization
# - Particle swarm optimization

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide instructions on how to use the interactive widgets to adjust the number of jobs and machines, and observe the resulting makespan and schedule changes.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# To use the interactive widgets:
# 1.  Locate the "Number of Jobs:" and "Number of Machines:" sliders.
# 2.  Adjust the sliders to your desired values (e.g., from 2 to 5 jobs and 2 to 5 machines).
# 3.  Each time you release a slider (after changing its value), the system will automatically:
#     *   Generate a new job shop problem with random machine orders and processing times for the specified number of jobs and machines.
#     *   Solve the problem using the PuLP optimization library.
#     *   Print the solution status, the calculated makespan, and the start times for each operation.
#     *   Update the Gantt chart visualization to display the new schedule.
#
# ### Data Analysis Key Findings
# *   The system successfully implemented dynamic problem generation, creating `machine_order` (a random permutation of machines for each job) and `processing_time` (random integers between 1 and 10 for each operation) based on interactive slider inputs for `num_jobs` and `num_machines`.
# *   A PuLP optimization model was integrated to solve the dynamically generated job shop problems, incorporating decision variables for start times and makespan, and comprehensive constraints for operation sequencing and no-overlap on machines.
# *   The `bigM` parameter, crucial for handling non-overlap constraints, is dynamically calculated based on the sum of current processing times, ensuring robustness for varying problem sizes.
# *   The solution, including the makespan and individual operation start times, is printed and visually represented by a dynamically generated Gantt chart.
# *   The Gantt chart visualization adapts its aesthetics, such as figure height, job-specific colors, and text sizes, to effectively display schedules for different numbers of jobs and machines.
# *   `ipywidgets.IntSlider` and `widgets.interactive` were successfully used to link the `num_jobs` and `num_machines` inputs to the problem-solving and visualization function, enabling real-time updates as users adjust the sliders.
#
# ### Insights or Next Steps
# *   This interactive tool provides a valuable educational resource for understanding the complexities of the Job Shop Scheduling Problem (JSSP) and the impact of varying job and machine counts on the optimal makespan and schedule.
# *   Future enhancements could include allowing users to input specific `machine_order` and `processing_time` values, or to compare different scheduling algorithms, further enriching the interactive learning experience.
